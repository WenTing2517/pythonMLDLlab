# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loss function and its after differential

# %%
def lossFunction(x):
    return x**2 + 10 * np.sin(x)

def diffLossFunction(x):
    return 2 * x + 10 * np.cos(x)

# %% [markdown]
# ## Gradient Descent

# %%
# xHistory: 紀錄所有的x
def GradientDescent(x_0, learningRate, iteration):
    xHistory = np.zeros(iteration + 1)    
    xHistory[0] = x_0 
    
    for i in range(iteration):         
        x_ite = xHistory[i] - learningRate * (diffLossFunction(xHistory[i]))
        xHistory[i + 1] = x_ite   
        
    return xHistory

# %% [markdown]
# ## Rsult
# * 點的顏色從藍色往紅色跑(彩虹色)，越接近紅色表示越後面找到的點

# %%
xStart = np.random.uniform(-10,10,1)
#xStart = 0
x = GradientDescent(xStart, 0.05, 1000)
t = np.linspace(-10, 10, 100)
plt.figure(figsize=(20,10))
plt.plot(t, lossFunction(t), c = 'darkslategrey')  
plt.scatter(x, lossFunction(x), c = x, cmap = 'rainbow')
